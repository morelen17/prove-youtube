# %%
import pandas as pd
from regression import add_categorical_columns, apply_regression
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df = pd.read_csv('./data_preprocessed/Allvideos.csv')
df = add_categorical_columns(df)
print(df)
# Out:
#          video_id                                              title  \
# 0     CwKp6Xhy3_4                           Chris Young - Hangin' On
# 1     OBOm_jatVCI            Blind Fast Food Sub Sandwich Taste Test
# 2     _IoOJu2_FKE  How Ticks Dig In With a Mouth Full of Hooks | ...
# 3     UJIo1AtoTss  Foster The People - Sit Next to Me (Around The...
# 4     MpaHR-V_R-o                               Gotta Catch ‘Em All!
# 5     OcTw2b0Ho-8     FALSE LASHES: Do's and Don'ts | For Beginners!
# 6     lgBn6qzMlXw  COLLEGE KIDS REACT TO TOP 10 MOST SUBSCRIBED Y...
# 7     ai6NByMmCVU                    Disney Princess Pushing A Truck
# 8     i04pYZGDHIc  How To Make a CHINESE FRIED RICE TAKEOUT CAKE ...
# 9     rNCT91V5dQU               Calum Scott - Come Back Home (Audio)
# 10    OZsYiWBgFOk  The Spy Who Dumped Me (2018 Movie) Teaser Trai...
# 11    pH7VfJDq7f4                                Why Bridges Move...
# 12    UmXbLTbi8Hg     Safe Neighborhood - Cyanide & Happiness Shorts
# ...

# %%
apply_regression('categorical', df, 'views')
apply_regression('tfidf', df, 'views')
apply_regression('par2vec', df, 'views')
apply_regression('sif', df, 'views')
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Predicting 'views' column (inputs - 'categorical'):
# Mean squared error: 2.33
# Explained variance score: 0.06
# Mean absolute error: 1.24
# Mean squared log error: 0.01
# Median absolute error: 1.09
# R2 score: -0.71
# -------
#
# Predicting 'views' column (inputs - 'tfidf'):
# Mean squared error: 4.61
# Explained variance score: -1.97
# Mean absolute error: 1.58
# Mean squared log error: 0.03
# Median absolute error: 1.17
# R2 score: -2.38
# -------
# /usr/local/lib/python3.5/dist-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Predicting 'views' column (inputs - 'par2vec'):
# ...

# %%
apply_regression('categorical', df, 'likes')
apply_regression('tfidf', df, 'likes')
apply_regression('par2vec', df, 'likes')
apply_regression('sif', df, 'likes')
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Predicting 'likes' column (inputs - 'categorical'):
# Mean squared error: 3.49
# Explained variance score: 0.10
# Mean absolute error: 1.52
# Mean squared log error: 0.05
# Median absolute error: 1.38
# R2 score: -0.20
# -------
#
# Predicting 'likes' column (inputs - 'tfidf'):
# Mean squared error: 3.98
# Explained variance score: -0.25
# Mean absolute error: 1.47
# Mean squared log error: 0.05
# Median absolute error: 1.14
# R2 score: -0.37
# -------
# /usr/local/lib/python3.5/dist-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Predicting 'likes' column (inputs - 'par2vec'):
# ...

# %%
apply_regression('categorical', df, 'dislikes')
apply_regression('tfidf', df, 'dislikes')
apply_regression('par2vec', df, 'dislikes')
apply_regression('sif', df, 'dislikes')
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Predicting 'dislikes' column (inputs - 'categorical'):
# Mean squared error: 3.12
# Explained variance score: 0.01
# Mean absolute error: 1.39
# Mean squared log error: 0.06
# Median absolute error: 1.13
# R2 score: -0.35
# -------
#
# Predicting 'dislikes' column (inputs - 'tfidf'):
# Mean squared error: 2.97
# Explained variance score: -0.20
# Mean absolute error: 1.33
# Mean squared log error: 0.07
# Median absolute error: 1.06
# R2 score: -0.29
# -------
# /usr/local/lib/python3.5/dist-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Predicting 'dislikes' column (inputs - 'par2vec'):
# ...
